# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Create a directory for extracted data and unzip the archive
# !mkdir -p /content/financial_data_extracted
# !unzip -o "/content/Financial Datasets for Python EDA.zip" -d "/content/financial_data_extracted"

# Define the correct path for the CSV after extraction
csv_file_path = "/content/financial_data_extracted/Company_Financials_India.csv"

# Load the CSV file
try:
    df = pd.read_csv(csv_file_path)
    print(f"Successfully loaded '{csv_file_path}'")
except FileNotFoundError:
    print(f"Error: The file '{csv_file_path}' was not found after extraction.")
    print("Please check the actual contents of the '/content/financial_data_extracted/' directory")
    print("using '!ls -R /content/financial_data_extracted' and adjust the 'csv_file_path' variable if necessary.")
# Out:
# Archive:  /content/Financial Datasets for Python EDA.zip
#   inflating: /content/financial_data_extracted/Regionwise_Sales_EDA_Dataset.csv
#   inflating: /content/financial_data_extracted/Walmart Data Analysis and Forcasting.csv
#   inflating: /content/financial_data_extracted/Company_Financials_India.csv
#   inflating: /content/financial_data_extracted/laptop_price_dataset_v4.csv
#   inflating: /content/financial_data_extracted/McDonalds_Financial_Statements.csv
#   inflating: /content/financial_data_extracted/NIFTY50_all.csv
# Successfully loaded '/content/financial_data_extracted/Company_Financials_India.csv'

# %%
df.head()
# Out:
#    Year  Revenue_INR_Crores  Operating_Expense_INR_Crores  \
# 0  2012             1051.43                        674.32
# 1  2013             1042.88                        693.73
# 2  2014             1193.64                        851.21
# 3  2015             1336.95                        832.24
# 4  2016             1386.00                        942.55
#
#    Net_Profit_INR_Crores  EBITDA_Margin_Percent  Debt_INR_Crores  \
# 0                 144.49                  20.45           793.47
# 1                 121.38                  24.89           753.23
# 2                 166.23                  26.42           803.22
# 3                 173.52                  23.45           794.15
# 4                 191.53                  25.21           725.10
#
#    Cash_and_Equivalents_INR_Crores  Capex_INR_Crores  EPS_INR  \
# 0                           124.04             71.87     4.17
# 1                           139.63            123.84     5.75
# ...

# %%
df.tail()
# Out:
#     Year  Revenue_INR_Crores  Operating_Expense_INR_Crores  \
# 8   2020             1977.73                       1405.99
# 9   2021             2073.53                       1313.20
# 10  2022             2120.81                       1425.91
# 11  2023             2268.87                       1576.96
# 12  2024             2430.32                       1669.39
#
#     Net_Profit_INR_Crores  EBITDA_Margin_Percent  Debt_INR_Crores  \
# 8                  247.45                  17.87           647.85
# 9                  302.34                  20.66           607.29
# 10                 258.92                  25.15           588.26
# 11                 309.08                  24.04           626.24
# 12                 311.66                  16.06           656.19
#
#     Cash_and_Equivalents_INR_Crores  Capex_INR_Crores  EPS_INR  \
# 8                            318.48            213.07    12.84
# 9                            375.02            282.45    13.19
# ...

# %%
df.shape
# Out:
# (13, 10)

# %%
df.columns
# Out:
# Index(['Year', 'Revenue_INR_Crores', 'Operating_Expense_INR_Crores',
#        'Net_Profit_INR_Crores', 'EBITDA_Margin_Percent', 'Debt_INR_Crores',
#        'Cash_and_Equivalents_INR_Crores', 'Capex_INR_Crores', 'EPS_INR',
#        'Dividend_per_Share_INR'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year                             13 non-null     int64
#  1   Revenue_INR_Crores               13 non-null     float64
#  2   Operating_Expense_INR_Crores     13 non-null     float64
#  3   Net_Profit_INR_Crores            13 non-null     float64
#  4   EBITDA_Margin_Percent            13 non-null     float64
#  5   Debt_INR_Crores                  13 non-null     float64
#  6   Cash_and_Equivalents_INR_Crores  13 non-null     float64
#  7   Capex_INR_Crores                 13 non-null     float64
#  8   EPS_INR                          13 non-null     float64
#  9   Dividend_per_Share_INR           13 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 1.1 KB

# %%
df.isnull().sum()
# Out:
# Year                               0
# Revenue_INR_Crores                 0
# Operating_Expense_INR_Crores       0
# Net_Profit_INR_Crores              0
# EBITDA_Margin_Percent              0
# Debt_INR_Crores                    0
# Cash_and_Equivalents_INR_Crores    0
# Capex_INR_Crores                   0
# EPS_INR                            0
# Dividend_per_Share_INR             0
# dtype: int64

# %%
df.ffill(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df['Year'] = df['Year'].astype(int)
